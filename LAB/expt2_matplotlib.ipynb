# %% [markdown]
# # Experiment 2: Matplotlib
# 1. Find the data distributions using box and scatter plot.
# 2. Find the outliers using plot
# 3. Plot the histogram, bar chart and pie chart on sample data.
# 4. Plot the Heat Map.

# %% [markdown]
# ## 1. Box plot

# %% [markdown]
# Box plots are the summary plots of the data distribution giving information like spread, skewness, whiskers, meadian and mean.

# %% [markdown]
# ### Box Plot

# %%
import matplotlib.pyplot as plt
help(plt.boxplot)

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Creating dataset
# The np.random.seed(1) function is a useful tool for debugging 
# and for ensuring that your code produces the same results each time it is run.
#np.random.seed(1.0) 

data_1 = np.random.normal(loc= 100, scale = 10, size =200) # mean, std, size
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

# boxplot
plt.figure(figsize = (8,6))
plt.boxplot(data, labels=['data_1', 'data_2', 'data_3','data_4'], 
            showmeans=True, 
            patch_artist=True, 
            vert=True)
xlabel = plt.xlabel('random numbers')
ylabel = plt.ylabel('group')
title = plt.title('Boxplot')


# Inserting text - showing quartiles
for i in range(0,4):
  Q1 = pd.DataFrame(data[i]).quantile(0.25)
  Q3 = pd.DataFrame(data[i]).quantile(0.75)
  plt.text(i+1, Q3+2, s = 'Q3(75%)', fontsize = 8)
  plt.text(i+1, Q1-7, s = 'Q1(25%)', fontsize = 8)
  median = pd.DataFrame(data[i]).median()
  plt.text(i+1, median, s = "median", fontsize = 8)
  
# show plot 
plt.show()

# %%
# replication

np.random.seed = 42
data1 = np.random.normal(loc = 100, scale = 10, size =200)
data2 = np.random.normal(90,8,200)
data3 = np.random.normal(80,7,200)
data4 = np.random.normal(70,6,200)
data = [data1,data2,data3,data4]
plt.boxplot(data, labels = ['d1','d2','d3','d4'],
            vert = True, showmeans = True, patch_artist=True, notch=True)
plt.xlabel("datas")
plt.ylabel("spread")
plt.show()

# %% [markdown]
# #### Finding Outliers

# %%
import pandas as pd
data1 = pd.DataFrame(data_1)

# Inter Quartile Range
Q1 = data1.quantile(0.25)
Q3 = data1.quantile(0.75)
IQR = Q3 - Q1

# Outliers
outlier = data1[(data1 < (Q1 - 1.5 * IQR)) | (data1 > (Q3 + 1.5 * IQR))].dropna()
print(outlier)
# Out:
#              0
# 166  58.638491

# %% [markdown]
# ### Histogram of data_1

# %%
# histogram of data_1
plt.hist(data_1, density=True, bins=30)
plt.title('Histogram of data_1')
plt.xlabel('data_1')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ### KDE of overall data

# %%
import seaborn as sns
sns.kdeplot(data, fill=True)
plt.xlabel('distribution of random numbers')
plt.title('KDE plot of data')
plt.legend(['data_1', 'data_2', 'data_3', 'data_4'])
plt.show()

# %% [markdown]
# ### expt Scatter Plot of data_1 and data_2

# %%
# Plot scatter plot for the data
plt.scatter(data_1, data_2, c='g', marker='o', s = 10, label='data_1 vs data_2')
plt.title('Scatter plot of data_1 vs data_2')
plt.xlabel('data_1')
plt.ylabel('data_2')
plt.show()

# %% [markdown]
# ## 2. Scatter Plot

# %%
help(plt.scatter)
# Out:
# Help on function scatter in module matplotlib.pyplot:
#
# scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)
#     A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
#     Parameters
#     ----------
#     x, y : float or array-like, shape (n, )
#         The data positions.
#
#     s : float or array-like, shape (n, ), optional
#         The marker size in points**2 (typographic points are 1/72 in.).
#         Default is ``rcParams['lines.markersize'] ** 2``.
#
#     c : array-like or list of colors or color, optional
#         The marker colors. Possible values:
#
#         - A scalar or sequence of n numbers to be mapped to colors using
#           *cmap* and *norm*.
#         - A 2D array in which the rows are RGB or RGBA.
#         - A sequence of colors of length n.
#         - A single color format string.
#
# ...

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y, c = 'b', marker = 'o', s = 20)
plt.title('Scatter plot of x vs y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 3. Histogram Plot

# %% [markdown]
# A histogram is a graph showing frequency distributions. It is a graph showing the number of observations within each given interval.

# %%
from matplotlib import pyplot as plt
import numpy as np

# Creating dataset
a = np.array([22, 87, 5, 43, 56,
      73, 55, 54, 11,
      20, 51, 5, 79, 31,
      27])

# Creating histogram
fig, ax = plt.subplots(figsize =(8, 6))
ax.hist(a, bins = [0, 25, 50, 75, 100]) #The bins are evenly spaced from 0 to 100, with a bin width of 25. 
# The height of each bar in the histogram represents the number of data points that fall within that bin.
plt.xlabel("bins")
plt.ylabel("frequency of values")
plt.title("Histogram")

# Show plot
plt.show()

# %%
# replication
data_h = [1,2,33,4,42,23,56,6,33,4,11,45,63,88,99,25]

plt.hist(data_h, bins = 5, )
plt.xlabel("data")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# ## 4. Bar Chart

# %%
# creating the dataset
# dictionary
data = {'C':20, 'C++':15, 'Java':30, 'Python':35}

#get the keys and values as separate lists
courses = list(data.keys())
values = list(data.values())

# creating the bar plot
plt.figure(figsize = (8, 6))
plt.bar(courses, values, color =['orange','blue','green','purple'], width = 0.4)
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# ## 5. Pie Chart

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np

# Creating dataset
cars = ['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]

# Creating plot
fig = plt.figure(figsize =(8, 6))
plt.pie(values, labels = courses)
plt.title("Pie chart", fontsize = 20)
plt.show()

# %% [markdown]
# ## 6. Heat Map

# %%
import seaborn as sns
# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low = 1, high = 100, size = (10, 10)) # matrix of 10x10
print("The data to be plotted:\n")
print(data)

# plotting the heatmap
hm = sns.heatmap(data = data, annot= True, cmap='viridis')
plt.title("Heat map of matrix")

# displaying the plotted heatmap
plt.show()
# Out:
# The data to be plotted:
#
# [[58  6 75 64 16 99 79 18 16 31]
#  [96  2 62 24 34 40  9 86 99 72]
#  [35 75 52 82 48 93 87 29 68 37]
#  [19 10 26 47 98 37 10 69 81 12]
#  [63 23 84 15 52 45 56 15 10 80]
#  [65 23 21 40 84 70 25  4 70 24]
#  [ 4 64 39 82 52 97 57  9 29  2]
#  [34 23 71 43 78 82  4 50  8  9]
#  [33 66  6 44 64 50 92 14 23 49]
#  [81 97 70 16  5 77 69 86 83 86]]
